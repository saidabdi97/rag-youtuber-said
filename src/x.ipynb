# %%
from google import genai
 
# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()
 
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="vart  ligger somalia",
)
print(response.text)
# Out:
# Somalia ligger i **östra Afrika**.
#
# Det utgör den östligaste delen av kontinentens fastland, och kallas ofta för en del av "Afrikas horn". Landet har en mycket lång kustlinje längs Indiska oceanen i öster och söder, samt Adenviken i norr.
#
# **Gränsar till:**
# *   **Etiopien** i väster
# *   **Kenya** i sydväst
# *   **Djibouti** i nordväst
